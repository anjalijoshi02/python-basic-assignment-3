# %% [markdown]
# # Python Basic Assignment-3

# %% [markdown]
# #### Question 1: Why are functions advantageous to have in your programs?

# %% [markdown]
# Functions reduce the need of duplicate codes, ie. we don't have to write same set of codes again and again.
# One of the main advantages of Functions is Code REUSABILITY

# %% [markdown]
# #### Question 2 : When does the code in a function run: when it&#39;s specified or when it&#39;s called?

# %% [markdown]
# The code in a function runs when IT IS CALLED.

# %% [markdown]
# #### Question 3: What statement creates a function?

# %% [markdown]
# def statement creates a function
# #### Syntax of a function
# def function_name(parameters):
#     """doc string"""
#     body of the function
#     return value

# %% [markdown]
# #### Question 4:  What is the difference between a function and a function call?

# %% [markdown]
# A function is a block of code that is used to perform a specific task.
# Function call : when we call a defined function to perform a particular task.

# %% [markdown]
# #### Question 5 : How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# One global scope and one local scpoe is created whenever a function is called.

# %% [markdown]
# #### Question 6 : What happens to variables in a local scope when the function call returns?

# %% [markdown]
# When the function call returns, the local scope is destroyed and the variables present in it are forgotten.

# %% [markdown]
# #### Question 7: What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# A return value is the value that a function call evaluates to.
# Yes, like any other value, it is possible to have a return value in an expression.

# %% [markdown]
# #### Question 8: If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# If a function does not have a return statement, then the return value of a call to that function is none type.

# %% [markdown]
# #### Question 9 : How do you make a function variable refer to the global variable?

# %% [markdown]
# A global statement will force a variable in a function to refer to global variable.
# If we want to refer to global variable in a function, we can use the global keyword to declare a global variable.

# %% [markdown]
# #### Question 10: What is the data type of None?

# %% [markdown]
# The data tyoe of none is NoneType

# %% [markdown]
# #### Question 11 : What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# Import statement imports a module named areallyourpetsnamederic.

# %% [markdown]
# #### Question 12: If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# This function be called using spam.bacon().

# %% [markdown]
# #### Question 13 : What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# Place the block of code which might cause an error in try clause and use except block to handle the error.

# %% [markdown]
# #### Question 14 : What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# The block of code that could potentially cause an error goes in the try clause.
# The code that executes in case an error occurs goes in except clause.
